# %% [markdown]
# # **Import Modules**

# %% [markdown]
# ## *python*

# %%
# Import python modules
import os
import sys

# %% [markdown]
# ## *custom*

# %%
# Import customised modules

# Define path
sys.path.append(os.path.abspath(os.path.join("..")))

# Import relevant modules
try:
    from scripts._03_train_model import TrainModel

    print("Module successfully imported.")

except ImportError:
    print("Could not import module from `scripts/`.")
# Out:
# Module successfully imported.

# %% [markdown]
# # **Model Training**

# %%
# Load class input paths
# Specify directory
ntbk_dir = os.getcwd()  # Gets the directory of the notebook

credit_path = os.path.join(
    ntbk_dir, "..", "data", "processed", "Train_Resampled_Scaled_Credit.csv"
)
test_x_c_path = os.path.join(
    ntbk_dir, "..", "data", "processed", "X_test_scaled_credit.csv."
)
test_y_c_path = os.path.join(ntbk_dir, "..", "data", "processed", "y_test_credit.csv")

fraud_path = os.path.join(
    ntbk_dir, "..", "data", "processed", "Train_Resampled_Scaled_Fraud.csv"
)
test_x_f_path = os.path.join(
    ntbk_dir, "..", "data", "processed", "X_test_scaled_fraud.csv"
)
test_y_f_path = os.path.join(ntbk_dir, "..", "data", "processed", "y_test_fraud.csv")

plot_dir = os.path.join(ntbk_dir, "..", "insights", "modelling")
model_dir = os.path.join(ntbk_dir, "..", "models")

# %% [markdown]
# ## *Initalise Class and Prep Data*

# %%
modelling = TrainModel(
    credit_path=credit_path,
    test_x_c_path=test_x_c_path,
    test_y_c_path=test_y_c_path,
    fraud_path=fraud_path,
    test_x_f_path=test_x_f_path,
    test_y_f_path=test_y_f_path,
    plot_dir=plot_dir,
    model_dir=model_dir,
)
# Out:
# TrainModel class initialised
#
#
# --- Credit Dataset ---
# Training data loaded from ..\data\processed\Train_Resampled_Scaled_Credit.csv
# Test features loaded from ..\data\processed\X_test_scaled_credit.csv
# Test targets loaded from ..\data\processed\y_test_credit.csv
#
# Credit Head:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  1.149234  1.310714 -1.479963  0.058213 -1.541434  0.818437  0.520080
# 1 -0.150917 -0.056665  0.108067  0.873613 -0.729778  0.195190 -0.030999
# 2  0.794158  1.183691 -0.653744  0.077048 -0.676187  0.893231  1.220875
# 3  0.065513  1.146161 -0.513946  0.790471 -0.725348  0.397123  1.551520
# 4 -1.193637  0.972088 -1.194275  0.859748 -1.212180 -0.157105  0.958065
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.014215  0.641489 -0.018312  ... -0.760135 -0.114507  1.001832  1.418833
# 1  0.611201  0.489997 -0.020360  ... -0.892635 -1.409402  1.146822  1.086614
# 2  0.541106 -0.184128  0.789507  ... -0.102734  1.537838 -0.029319  0.154380
# 3  0.328239 -0.119330  0.997019  ... -0.332270  0.967295  0.668938  1.454711
# 4  0.188725 -0.144545 -0.451643  ... -1.044048 -0.961633  0.919916 -0.602530
#
#         V25       V26       V27       V28    Amount  Class
# 0 -0.593265 -0.425813 -0.493744 -0.628815 -0.060453      0
# 1 -1.626604 -0.687742 -0.625605 -0.174278 -0.624841      0
# 2  0.086865 -0.018471 -0.476599 -0.642930 -0.445212      0
# 3 -0.579658 -0.061848 -0.625476 -0.575139 -0.392180      0
# 4 -0.269552 -1.110198 -0.435513 -0.345143 -0.240985      0
#
# [5 rows x 31 columns]
# Credit Shape: (453204, 31)
#
# Credit Columns: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']
#
# Credit Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453204 entries, 0 to 453203
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    453204 non-null  float64
#  1   V1      453204 non-null  float64
#  2   V2      453204 non-null  float64
#  3   V3      453204 non-null  float64
#  4   V4      453204 non-null  float64
#  5   V5      453204 non-null  float64
#  6   V6      453204 non-null  float64
#  7   V7      453204 non-null  float64
#  8   V8      453204 non-null  float64
#  9   V9      453204 non-null  float64
#  10  V10     453204 non-null  float64
#  11  V11     453204 non-null  float64
#  12  V12     453204 non-null  float64
#  13  V13     453204 non-null  float64
#  14  V14     453204 non-null  float64
#  15  V15     453204 non-null  float64
#  16  V16     453204 non-null  float64
#  17  V17     453204 non-null  float64
#  18  V18     453204 non-null  float64
#  19  V19     453204 non-null  float64
#  20  V20     453204 non-null  float64
#  21  V21     453204 non-null  float64
#  22  V22     453204 non-null  float64
#  23  V23     453204 non-null  float64
#  24  V24     453204 non-null  float64
#  25  V25     453204 non-null  float64
#  26  V26     453204 non-null  float64
#  27  V27     453204 non-null  float64
#  28  V28     453204 non-null  float64
#  29  Amount  453204 non-null  float64
#  30  Class   453204 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 107.2 MB
#
# --- Fraud Dataset ---
# Training data loaded from ..\data\processed\Train_Resampled_Scaled_Fraud.csv
# Test features loaded from ..\data\processed\X_test_scaled_fraud.csv
# Test targets loaded from ..\data\processed\y_test_fraud.csv
#
# Fraud Head:
#    Purchase_Value       Age  Ip_Address  Fraud_Rate  User_Transaction_Count  \
# 0       -0.562402 -1.474087    0.109952   -0.018896                     0.0
# 1       -0.167527  1.656013    0.112572   -0.018896                     0.0
# 2        0.227347  0.933683    0.975297   -0.018896                     0.0
# 3        0.622222 -0.992533   -0.891481   -0.181215                     0.0
# 4        1.129918 -1.714864    0.538853   -0.018896                     0.0
#
#    Device_Transaction_Count  Time_Since_Last  Velocity  Hour_Of_Day  \
# 0                 -0.639528        -0.198806 -0.399204    -0.084533
# 1                 -0.639528        -0.198806 -0.399204     1.727241
# 2                 -0.639528        -0.198806 -0.399204    -1.594345
# 3                 -0.639528        -0.198806 -0.399204     0.519392
# 4                 -0.639528        -0.198806 -0.399204    -1.594345
#
#    Time_Since_Signup  Class
# 0           1.389557      0
# 1          -0.224353      0
# 2           1.850381      0
# 3          -0.901321      0
# 4           0.689955      0
# Fraud Shape: (219136, 11)
#
# Fraud Columns: ['Purchase_Value', 'Age', 'Ip_Address', 'Fraud_Rate', 'User_Transaction_Count', 'Device_Transaction_Count', 'Time_Since_Last', 'Velocity', 'Hour_Of_Day', 'Time_Since_Signup', 'Class']
#
# Fraud Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219136 entries, 0 to 219135
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Purchase_Value            219136 non-null  float64
#  1   Age                       219136 non-null  float64
#  2   Ip_Address                219136 non-null  float64
#  3   Fraud_Rate                219136 non-null  float64
#  4   User_Transaction_Count    219136 non-null  float64
#  5   Device_Transaction_Count  219136 non-null  float64
#  6   Time_Since_Last           219136 non-null  float64
#  7   Velocity                  219136 non-null  float64
#  8   Hour_Of_Day               219136 non-null  float64
#  9   Time_Since_Signup         219136 non-null  float64
#  10  Class                     219136 non-null  int64
# dtypes: float64(10), int64(1)
# memory usage: 18.4 MB

# %% [markdown]
# ## *Model Training and Evaluation*

# %%
modelling.train_and_evaluate()
# Out:
# --- Credit Dataset ---
#
# Training Logistic Regression on Credit...
# Credit F1-Score Logistic Regression: 0.2771
# Credit AUC-PR Logistic Regression: 0.8609
# Credit Confusion Matrix Logistic Regression:
# [[56230   421]
#  [   12    83]]
#
# Confusion matrix saved to ..\insights\modelling\Credit_cm_Logistic_Regression.png
# Precision-Recall curve saved to ..\insights\modelling\Credit_pr_Logistic_Regression.png
# Training Random Forest on Credit...
# Credit F1-Score Random Forest: 0.9570
# Credit AUC-PR Random Forest: 0.9575
# Credit Confusion Matrix Random Forest:
# [[56649     2]
#  [    6    89]]
#
# Confusion matrix saved to ..\insights\modelling\Credit_cm_Random_Forest.png
# Precision-Recall curve saved to ..\insights\modelling\Credit_pr_Random_Forest.png
# Training XG Boost on Credit...
# Credit F1-Score XG Boost: 0.9231
# Credit AUC-PR XG Boost: 0.8998
# Credit Confusion Matrix XG Boost:
# [[56648     3]
#  [   11    84]]
#
# Confusion matrix saved to ..\insights\modelling\Credit_cm_XG_Boost.png
# Precision-Recall curve saved to ..\insights\modelling\Credit_pr_XG_Boost.png
# Best model for Credit saved to ..\models\Credit_best_model_Random_Forest.pkl
#
# --- Fraud Dataset ---
#
# Training Logistic Regression on Fraud...
# Fraud F1-Score Logistic Regression: 0.6152
# Fraud AUC-PR Logistic Regression: 0.6530
# Fraud Confusion Matrix Logistic Regression:
# [[26117  1276]
#  [ 1006  1824]]
#
# Confusion matrix saved to ..\insights\modelling\Fraud_cm_Logistic_Regression.png
# Precision-Recall curve saved to ..\insights\modelling\Fraud_pr_Logistic_Regression.png
# Training Random Forest on Fraud...
# Fraud F1-Score Random Forest: 0.6740
# Fraud AUC-PR Random Forest: 0.7000
# Fraud Confusion Matrix Random Forest:
# [[27109   284]
#  [ 1247  1583]]
#
# Confusion matrix saved to ..\insights\modelling\Fraud_cm_Random_Forest.png
# Precision-Recall curve saved to ..\insights\modelling\Fraud_pr_Random_Forest.png
# Training XG Boost on Fraud...
# Fraud F1-Score XG Boost: 0.6890
# Fraud AUC-PR XG Boost: 0.7097
# Fraud Confusion Matrix XG Boost:
# [[27346    47]
#  [ 1318  1512]]
#
# Confusion matrix saved to ..\insights\modelling\Fraud_cm_XG_Boost.png
# Precision-Recall curve saved to ..\insights\modelling\Fraud_pr_XG_Boost.png
# Best model for Fraud saved to ..\models\Fraud_best_model_XG_Boost.pkl
