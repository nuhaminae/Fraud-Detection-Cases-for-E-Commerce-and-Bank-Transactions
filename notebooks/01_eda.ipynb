# %% [markdown]
# # **Import Modules**

# %% [markdown]
# ## *python*

# %%
# Import python modules
import os
import sys

# %% [markdown]
# ## *custom*

# %%
# Import customised modules

# Define path
sys.path.append(os.path.abspath(os.path.join("..")))

# Import relevant modules
try:
    from scripts._01_data_preprocessing import EDA

    print("Module successfully imported.")

except ImportError:
    print("Could not import module from `scripts/`.")
# Out:
# Module successfully imported.

# %% [markdown]
# # **Data Analysis and Preprocessing**

# %%
# Load class input paths
# Specify directory
ntbk_dir = os.getcwd()  # Gets the directory of the notebook

credit_path = os.path.join(ntbk_dir, "..", "data", "raw", "CreditCard.csv")
fraud_path = os.path.join(ntbk_dir, "..", "data", "raw", "FraudData.csv")
ip_path = os.path.join(ntbk_dir, "..", "data", "raw", "IPAddressToCountry.csv")

plot_dir = os.path.join(ntbk_dir, "..", "insights", "eda")
processed_dir = os.path.join(ntbk_dir, "..", "data", "processed")

# %% [markdown]
# ## *Initalise Class*

# %%
eda = EDA(
    credit_path=credit_path,
    fraud_path=fraud_path,
    ip_path=ip_path,
    plot_dir=plot_dir,
    processed_dir=processed_dir,
)
# Out:
# EDA class is Initialised
#
# CreditCard loaded from ..\data\raw\CreditCard.csv
# CreditCard Head:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# ...

# %% [markdown]
# ## *Data Cleaning*

# %%
eda.data_cleaning()
# Out:
# CreditCard: Removed 1081 duplicate rows.
# CreditCard: Datatypes changed.
#
# New CreditCard Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 283726 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    283726 non-null  float64
#  1   V1      283726 non-null  float64
#  2   V2      283726 non-null  float64
#  3   V3      283726 non-null  float64
#  4   V4      283726 non-null  float64
#  5   V5      283726 non-null  float64
#  6   V6      283726 non-null  float64
#  7   V7      283726 non-null  float64
#  8   V8      283726 non-null  float64
#  9   V9      283726 non-null  float64
#  10  V10     283726 non-null  float64
#  11  V11     283726 non-null  float64
#  12  V12     283726 non-null  float64
#  13  V13     283726 non-null  float64
#  14  V14     283726 non-null  float64
#  15  V15     283726 non-null  float64
#  16  V16     283726 non-null  float64
# ...

# %% [markdown]
# ## *Handle Missing Values*

# %%
eda.missing_values()
# Out:
# CreditCard: No missing values found.
# FraudData: No missing values found.
# IPAddress Map: No missing values found.

# %% [markdown]
# ## *Univariate Analysis*

# %%
eda.univariate()
# Out:
# CreditCard: Visualising numerical values ...
#
# Plot saved to ..\insights\eda\CreditCard_Time_hist.png
# Plot saved to ..\insights\eda\CreditCard_V1_hist.png
# Plot saved to ..\insights\eda\CreditCard_V2_hist.png
# Plot saved to ..\insights\eda\CreditCard_V3_hist.png
# Plot saved to ..\insights\eda\CreditCard_V4_hist.png
# Plot saved to ..\insights\eda\CreditCard_V5_hist.png
# Plot saved to ..\insights\eda\CreditCard_V6_hist.png
# Plot saved to ..\insights\eda\CreditCard_V7_hist.png
# Plot saved to ..\insights\eda\CreditCard_V8_hist.png
# Plot saved to ..\insights\eda\CreditCard_V9_hist.png
# Plot saved to ..\insights\eda\CreditCard_V10_hist.png
# Plot saved to ..\insights\eda\CreditCard_V11_hist.png
# Plot saved to ..\insights\eda\CreditCard_V12_hist.png
# Plot saved to ..\insights\eda\CreditCard_V13_hist.png
# Plot saved to ..\insights\eda\CreditCard_V14_hist.png
# Plot saved to ..\insights\eda\CreditCard_V15_hist.png
# Plot saved to ..\insights\eda\CreditCard_V16_hist.png
# ...

# %% [markdown]
# ## *Bivariate Analysis*

# %%
eda.bivariate()
# Out:
# CreditCard: Visualising outliers ...
#
# Plot saved to ..\insights\eda\CreditCard_Time_box.png
# Plot saved to ..\insights\eda\CreditCard_V1_box.png
# Plot saved to ..\insights\eda\CreditCard_V2_box.png
# Plot saved to ..\insights\eda\CreditCard_V3_box.png
# Plot saved to ..\insights\eda\CreditCard_V4_box.png
# Plot saved to ..\insights\eda\CreditCard_V5_box.png
# Plot saved to ..\insights\eda\CreditCard_V6_box.png
# Plot saved to ..\insights\eda\CreditCard_V7_box.png
# Plot saved to ..\insights\eda\CreditCard_V8_box.png
# Plot saved to ..\insights\eda\CreditCard_V9_box.png
# Plot saved to ..\insights\eda\CreditCard_V10_box.png
# Plot saved to ..\insights\eda\CreditCard_V11_box.png
# Plot saved to ..\insights\eda\CreditCard_V12_box.png
# Plot saved to ..\insights\eda\CreditCard_V13_box.png
# Plot saved to ..\insights\eda\CreditCard_V14_box.png
# Plot saved to ..\insights\eda\CreditCard_V15_box.png
# Plot saved to ..\insights\eda\CreditCard_V16_box.png
# ...

# %% [markdown]
# ## *Handle Outliers*

# %%
eda.impute_outliers_iqr_zscore()
# Out:
# CreditCard: Outliers handled.
# CreditCard: Processed DataFrame saved to ..\data\processed.
#
# FraudData: Outliers handled.
# FraudData: Processed DataFrame saved to ..\data\processed.
#
# IPAddressMap: 'Class' column not found. Skipping class-aware imputation.
# IPAddressMap: Processed DataFrame saved to ..\data\processed.

# %% [markdown]
# ## *Merge and Save*

# %%
eda.apply_map_ip_to_country()
# Out:
# 21966 IPs could not be mapped to any country.
# Merged DataFrame 'MapIPtoCountry' saved to ..\data\processed.
