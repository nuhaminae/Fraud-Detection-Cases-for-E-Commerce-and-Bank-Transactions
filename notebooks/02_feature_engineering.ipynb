# %% [markdown]
# # **Import Modules**

# %% [markdown]
# ## *python*

# %%
# Import python modules
import os
import sys

# %% [markdown]
# ## *custom*

# %%
# Import customised modules

# Define path
sys.path.append(os.path.abspath(os.path.join("..")))

# Import relevant modules
try:
    from scripts._02_feature_engineering import FeatureEngineering

    print("Module successfully imported.")

except ImportError:
    print("Could not import module from `scripts/`.")
# Out:
# Module successfully imported.

# %% [markdown]
# # **Feature Engineering**

# %%
# Load class input paths
# Specify directory
ntbk_dir = os.getcwd()  # Gets the directory of the notebook

fraud_path = os.path.join(
    ntbk_dir, "..", "data", "processed", "FraudData_processed.csv"
)

plot_dir = os.path.join(ntbk_dir, "..", "insights", "feature_engineering")
processed_dir = os.path.join(ntbk_dir, "..", "data", "processed")

# %% [markdown]
# ## *Initalise Class*

# %%
engineering = FeatureEngineering(
    fraud_path=fraud_path, processed_dir=processed_dir, plot_dir=plot_dir
)
# Out:
# FeatureEngineering class is Initialised
#
# DataFrame loaded from ..\data\processed\FraudData_processed.csv
# DataFrame Head:
#   User_Id         Signup_Time       Purchase_Time  Purchase_Value  \
# 0   22058 2015-02-24 22:55:49 2015-04-18 02:47:11            34.0
# 1  333320 2015-06-07 20:39:50 2015-06-08 01:38:54            16.0
# 2    1359 2015-01-01 18:52:44 2015-01-01 18:52:45            15.0
# 3  150084 2015-04-28 21:13:25 2015-05-04 13:54:50            44.0
# 4  221365 2015-07-21 07:09:52 2015-09-09 18:40:53            39.0
#
#        Device_Id Source Browser Sex  Age  Ip_Address  Class
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39   732758369      0
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53   350311388      0
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2621473820      1
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3840542444      0
# 4  NAUITBZFJKHWW    Ads  Safari   M   45   415583117      0
# DataFrame Shape: (151112, 11)
#
# DataFrame Columns: ['User_Id', 'Signup_Time', 'Purchase_Time', 'Purchase_Value', 'Device_Id', 'Source', 'Browser', 'Sex', 'Age', 'Ip_Address', 'Class']
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151112 entries, 0 to 151111
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   User_Id         151112 non-null  object
#  1   Signup_Time     151112 non-null  datetime64[ns]
#  2   Purchase_Time   151112 non-null  datetime64[ns]
#  3   Purchase_Value  151112 non-null  float64
#  4   Device_Id       151112 non-null  object
#  5   Source          151112 non-null  object
#  6   Browser         151112 non-null  object
#  7   Sex             151112 non-null  object
#  8   Age             151112 non-null  int64
#  9   Ip_Address      151112 non-null  int64
#  10  Class           151112 non-null  int64
# dtypes: datetime64[ns](2), float64(1), int64(3), object(5)
# memory usage: 12.7+ MB

# %%
engineering.transaction_frequency_Velocity()
# Out:
# Plot saved to ..\insights\feature_engineering
# Plot saved to ..\insights\feature_engineering
# Plot saved to ..\insights\feature_engineering
# Enriched fraud data saved to ..\data\processed\FraudData_FeatureEngineered.csv
#        User_Id         Signup_Time       Purchase_Time  Purchase_Value  \
# 116708       2 2015-01-11 03:47:13 2015-02-21 10:03:37            54.0
# 15108        4 2015-06-02 16:40:57 2015-09-26 21:32:16            41.0
# 46047        8 2015-05-28 07:53:06 2015-08-13 11:53:07            47.0
# 67650        9 2015-05-16 15:58:32 2015-05-20 23:06:42            62.0
# 109067      12 2015-01-10 06:25:12 2015-03-04 20:56:37            35.0
# ...        ...                 ...                 ...             ...
# 143144  399992 2015-06-04 17:43:28 2015-09-30 07:19:17            82.0
# 103577  399993 2015-07-30 03:41:08 2015-10-01 07:16:25            20.0
# 6412    399995 2015-03-10 05:19:31 2015-06-05 23:36:56            33.0
# 139579  399997 2015-06-30 09:02:16 2015-10-07 20:56:54            66.0
# 109602  400000 2015-03-16 23:03:56 2015-04-20 06:27:52            58.0
#
#             Device_Id  Source  Browser Sex  Age  Ip_Address  Class  \
# 116708  FGBQNDNBETFJJ     SEO   Chrome   F   25   880217485      0
# 15108   MKFUIVOHLJBYN  Direct   Safari   F   38  2785906107      0
# 46047   SCQGQALXBUQZJ     SEO   Chrome   M   25   356056737      0
# 67650   IEZOHXPZBIRTE     SEO  FireFox   M   21   759104706      0
# 109067  MSNWCFEHKTIOY     Ads   Safari   M   19  2985180353      0
# ...               ...     ...      ...  ..  ...         ...    ...
# 143144  CNVFEDSCAWXGS  Direct   Safari   M   33  1549469282      0
# 103577  XJMTBAKOHKTGR  Direct       IE   F   37  2755338336      0
# 6412    RYXNXTOXIYRQG  Direct  FireFox   F   35  3701447304      0
# 139579  XFNGDCCMMBTCB  Direct   Chrome   M   48  3454704355      0
# 109602  ACINFPOJYYUAW     Ads   Chrome   M   25  1217910956      1
#
#         User_Transaction_Count  Device_Transaction_Count  Time_Since_Last  \
# 116708                       1                         1             -1.0
# 15108                        1                         1             -1.0
# 46047                        1                         1             -1.0
# 67650                        1                         1             -1.0
# 109067                       1                         1             -1.0
# ...                        ...                       ...              ...
# 143144                       1                         1             -1.0
# 103577                       1                         1             -1.0
# 6412                         1                         1             -1.0
# 139579                       1                         1             -1.0
# 109602                       1                         1             -1.0
#
#         Velocity  Hour_Of_Day  Day_Of_Week  Time_Since_Signup
# 116708     -54.0           10            5          3564984.0
# 15108      -41.0           21            5         10039879.0
# 46047      -47.0           11            3          6667201.0
# 67650      -62.0           23            2           371290.0
# 109067     -35.0           20            2          4631485.0
# ...          ...          ...          ...                ...
# 143144     -82.0            7            2         10157749.0
# 103577     -20.0            7            3          5456117.0
# 6412       -33.0           23            4          7582645.0
# 139579     -66.0           20            2          8596478.0
# 109602     -58.0            6            0          2964236.0
#
# [151112 rows x 18 columns]

# %%
engineering.data_transformation()
# Out:
# Original Fraud Ratio: 9.36%
# Shape before SMOTE: (120889, 10), aafter SMOTE: (219136, 10)
# Resampled Fraud Ratio: 50.00%
# Resampled and scaled training data 'Train_Resampled_Scaled'saved to ..\data\processed\Train_Resampled_Scaled.csv.
# Class Distribution Bar Plot After Class Balancing...
#
# Plot saved to ..\insights\feature_engineering\new_class_count.png
