# %% [markdown]
# # **Import Modules**

# %% [markdown]
# ## *python*

# %%
# Import python modules
import os
import sys

# %% [markdown]
# ## *custom*

# %%
# Import customised modules

# Define path
sys.path.append(os.path.abspath(os.path.join("..")))

# Import relevant modules
try:
    from scripts._02_feature_engineering import FeatureEngineering

    print("Module successfully imported.")

except ImportError:
    print("Could not import module from `scripts/`.")
# Out:
# Module successfully imported.

# %% [markdown]
# # **Feature Engineering**

# %%
# Load class input paths
# Specify directory
ntbk_dir = os.getcwd()  # Gets the directory of the notebook

credit_path = os.path.join(
    ntbk_dir, "..", "data", "processed", "CreditCard_processed.csv"
)
fraud_path = os.path.join(ntbk_dir, "..", "data", "processed", "MapIPtoCountry.csv")

plot_dir = os.path.join(ntbk_dir, "..", "insights", "feature_engineering")
processed_dir = os.path.join(ntbk_dir, "..", "data", "processed")

# %% [markdown]
# ## *Initialise Class*

# %%
engineering = FeatureEngineering(
    credit_path=credit_path,
    fraud_path=fraud_path,
    processed_dir=processed_dir,
    plot_dir=plot_dir,
)
# Out:
# FeatureEngineering class is initialised
#
# DataFrame loaded from ..\data\processed\CreditCard_processed.csv
# CreditCard Head:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679 -0.011077 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752   22.00      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]
# CreditCardShape: (283726, 31)
#
# CreditCardColumns: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']
#
# CreditCardInfo:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283726 entries, 0 to 283725
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    283726 non-null  float64
#  1   V1      283726 non-null  float64
#  2   V2      283726 non-null  float64
#  3   V3      283726 non-null  float64
#  4   V4      283726 non-null  float64
#  5   V5      283726 non-null  float64
#  6   V6      283726 non-null  float64
#  7   V7      283726 non-null  float64
#  8   V8      283726 non-null  float64
#  9   V9      283726 non-null  float64
#  10  V10     283726 non-null  float64
#  11  V11     283726 non-null  float64
#  12  V12     283726 non-null  float64
#  13  V13     283726 non-null  float64
#  14  V14     283726 non-null  float64
#  15  V15     283726 non-null  float64
#  16  V16     283726 non-null  float64
#  17  V17     283726 non-null  float64
#  18  V18     283726 non-null  float64
#  19  V19     283726 non-null  float64
#  20  V20     283726 non-null  float64
#  21  V21     283726 non-null  float64
#  22  V22     283726 non-null  float64
#  23  V23     283726 non-null  float64
#  24  V24     283726 non-null  float64
#  25  V25     283726 non-null  float64
#  26  V26     283726 non-null  float64
#  27  V27     283726 non-null  float64
#  28  V28     283726 non-null  float64
#  29  Amount  283726 non-null  float64
#  30  Class   283726 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.1 MB
#
# *==**==**==**==**==**==**==**==**==**==**==**==**==**==**==**==**==**==**==**==*
#
# DataFrame loaded from ..\data\processed\MapIPtoCountry.csv
# FraudData Head:
#   User_Id         Signup_Time       Purchase_Time  Purchase_Value  \
# 0       2 2015-01-11 03:47:13 2015-02-21 10:03:37            54.0
# 1       4 2015-06-02 16:40:57 2015-09-26 21:32:16            41.0
# 2       8 2015-05-28 07:53:06 2015-08-13 11:53:07            47.0
# 3       9 2015-05-16 15:58:32 2015-05-20 23:06:42            62.0
# 4      12 2015-01-10 06:25:12 2015-03-04 20:56:37            35.0
#
#        Device_Id  Source  Browser Sex  Age  Ip_Address  Class        Country  \
# 0  FGBQNDNBETFJJ     SEO   Chrome   F   25   880217485      0  United States
# 1  MKFUIVOHLJBYN  Direct   Safari   F   38  2785906107      0    Switzerland
# 2  SCQGQALXBUQZJ     SEO   Chrome   M   25   356056737      0  United States
# 3  IEZOHXPZBIRTE     SEO  FireFox   M   21   759104706      0        Unknown
# 4  MSNWCFEHKTIOY     Ads   Safari   M   19  2985180353      0         Mexico
#
#    Fraud_Rate
# 0    0.095626
# 1    0.087898
# 2    0.095626
# 3    0.085723
# 4    0.128457
# FraudDataShape: (151112, 13)
#
# FraudDataColumns: ['User_Id', 'Signup_Time', 'Purchase_Time', 'Purchase_Value', 'Device_Id', 'Source', 'Browser', 'Sex', 'Age', 'Ip_Address', 'Class', 'Country', 'Fraud_Rate']
#
# FraudDataInfo:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151112 entries, 0 to 151111
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   User_Id         151112 non-null  object
#  1   Signup_Time     151112 non-null  datetime64[ns]
#  2   Purchase_Time   151112 non-null  datetime64[ns]
#  3   Purchase_Value  151112 non-null  float64
#  4   Device_Id       151112 non-null  object
#  5   Source          151112 non-null  object
#  6   Browser         151112 non-null  object
#  7   Sex             151112 non-null  object
#  8   Age             151112 non-null  int64
#  9   Ip_Address      151112 non-null  int64
#  10  Class           151112 non-null  int64
#  11  Country         151112 non-null  object
#  12  Fraud_Rate      151112 non-null  float64
# dtypes: datetime64[ns](2), float64(2), int64(3), object(6)
# memory usage: 15.0+ MB
#
# *==**==**==**==**==**==**==**==**==**==**==**==**==**==**==**==**==**==**==**==*

# %% [markdown]
# ## *Engineer Feature*

# %%
engineering.transaction_frequency_Velocity()
# Out:
# Plot saved to ..\insights\feature_engineering
# Plot saved to ..\insights\feature_engineering
# Plot saved to ..\insights\feature_engineering
# Enriched fraud data saved to ..\data\processed\FraudData_FeatureEngineered.csv
#        User_Id         Signup_Time       Purchase_Time  Purchase_Value  \
# 85648   226648 2015-05-12 16:00:31 2015-06-13 23:42:18            45.0
# 38815   103319 2015-02-05 22:20:04 2015-03-29 00:39:07            94.0
# 13786    36633 2015-05-10 00:49:53 2015-07-22 03:18:01            46.0
# 123070  325729 2015-01-01 04:25:22 2015-01-01 04:25:23            57.0
# 24241    64674 2015-01-01 04:25:23 2015-01-01 04:25:24            57.0
# ...        ...                 ...                 ...             ...
# 109980  291289 2015-04-05 21:31:06 2015-04-12 04:54:26            18.0
# 2504      6741 2015-08-16 09:46:26 2015-10-24 17:29:39            55.0
# 46157   122422 2015-08-09 14:05:16 2015-09-07 03:15:41            59.0
# 135663  359303 2015-05-10 11:55:20 2015-08-06 10:45:33            49.0
# 53785   142603 2015-05-08 19:20:08 2015-05-23 19:19:02            82.0
#
#             Device_Id  Source  Browser Sex  Age  Ip_Address  Class  \
# 85648   AAALBGNHHVMKG  Direct   Chrome   M   34  2494581089      0
# 38815   AAAWIHVCQELTP     Ads   Chrome   M   29   809263681      0
# 13786   AAAXJHWCLISKY     Ads       IE   M   40     2891497      0
# 123070  AAAXXOZJRZRAO     Ads  FireFox   F   36  1377849233      1
# 24241   AAAXXOZJRZRAO     Ads  FireFox   F   36  1377849233      1
# ...               ...     ...      ...  ..  ...         ...    ...
# 109980  ZZZGSIJRNCXBJ     Ads   Safari   F   33  2553895471      0
# 2504    ZZZIKLJSVSQMF     Ads       IE   M   41  3265673644      0
# 46157   ZZZKJIZHJEDFN  Direct   Safari   M   33  2415066584      0
# 135663  ZZZMVOGBAJVTM     Ads   Chrome   M   25  3404179484      0
# 53785   ZZZXASJUVUNMV  Direct   Chrome   F   56  4035153773      0
#
#                Country  Fraud_Rate  User_Transaction_Count  \
# 85648   United Kingdom    0.106236                       1
# 38815    United States    0.095626                       1
# 13786          Unknown    0.085723                       1
# 123070  United Kingdom    0.106236                       1
# 24241   United Kingdom    0.106236                       1
# ...                ...         ...                     ...
# 109980   United States    0.095626                       1
# 2504           Austria    0.075862                       1
# 46157    United States    0.095626                       1
# 135663           Japan    0.097865                       1
# 53785          Unknown    0.085723                       1
#
#         Device_Transaction_Count  Time_Since_Last  Velocity  Hour_Of_Day  \
# 85648                          1              NaN       NaN           23
# 38815                          1              NaN       NaN            0
# 13786                          1              NaN       NaN            3
# 123070                        11              NaN       NaN            4
# 24241                         11              1.0      57.0            4
# ...                          ...              ...       ...          ...
# 109980                         1              NaN       NaN            4
# 2504                           1              NaN       NaN           17
# 46157                          1              NaN       NaN            3
# 135663                         1              NaN       NaN           10
# 53785                          1              NaN       NaN           19
#
#        Day_Of_Week  Time_Since_Signup
# 85648     Saturday          2792507.0
# 38815       Sunday          4414743.0
# 13786    Wednesday          6316088.0
# 123070    Thursday                1.0
# 24241     Thursday                1.0
# ...            ...                ...
# 109980      Sunday           545000.0
# 2504      Saturday          5989393.0
# 46157       Monday          2466625.0
# 135663    Thursday          7599013.0
# 53785     Saturday          1295934.0
#
# [151112 rows x 20 columns]

# %% [markdown]
# ## *Transform Data*

# %%
engineering.fraud_data_transformation()
# Out:
# Original Fraud Ratio: 9.36%
#
# Shape before SMOTE: (120889, 10)
# Shape after SMOTE: (219136, 10)
#
# Resampled Fraud Ratio: 50.00%
# Resampled and scaled training data 'Train_Resampled_Scaled_Fraud' saved                 to ..\data\processed\Train_Resampled_Scaled_Fraud.csv.
#
# Class Distribution Bar Plot After Class Balancing...
#
# Plot saved to ..\insights\feature_engineering\fraud_new_class_count.png
#         Purchase_Value       Age  Ip_Address  Fraud_Rate  \
# 0            -0.562402 -1.474087    0.109952   -0.018896
# 1            -0.167527  1.656013    0.112572   -0.018896
# 2             0.227347  0.933683    0.975297   -0.018896
# 3             0.622222 -0.992533   -0.891481   -0.181215
# 4             1.129918 -1.714864    0.538853   -0.018896
# ...                ...       ...         ...         ...
# 219131       -0.336759  2.017179    0.808377   -0.185602
# 219132       -1.577793 -0.390591   -0.583232   -0.911101
# 219133        0.678633 -0.149814   -1.466827   -0.018896
# 219134       -0.150316 -0.270202   -1.699188    2.082327
# 219135        1.411971  0.692906    1.701015   -0.390648
#
#         User_Transaction_Count  Device_Transaction_Count  Time_Since_Last  \
# 0                          0.0                 -0.639528        -0.198806
# 1                          0.0                 -0.639528        -0.198806
# 2                          0.0                 -0.639528        -0.198806
# 3                          0.0                 -0.639528        -0.198806
# 4                          0.0                 -0.639528        -0.198806
# ...                        ...                       ...              ...
# 219131                     0.0                  1.700198        -0.198806
# 219132                     0.0                  0.920289        -0.198806
# 219133                     0.0                  2.090153        -0.198806
# 219134                     0.0                  1.675004        -0.198806
# 219135                     0.0                  1.700198        -0.198806
#
#         Velocity  Hour_Of_Day  Time_Since_Signup  Class
# 0      -0.399204    -0.084533           1.389557      0
# 1      -0.399204     1.727241          -0.224353      0
# 2      -0.399204    -1.594345           1.850381      0
# 3      -0.399204     0.519392          -0.901321      0
# 4      -0.399204    -1.594345           0.689955      0
# ...          ...          ...                ...    ...
# 219131  0.898824     0.972335          -1.097023      1
# 219132 -0.604156    -1.443364          -1.097023      1
# 219133  2.128534    -0.235514          -1.097023      1
# 219134  1.035606    -0.077813          -1.049668      1
# 219135  3.016659    -0.386496          -1.097023      1
#
# [219136 rows x 11 columns]

# %%
engineering.credit_data_transformation()
# Out:
# Original Fraud Ratio: 0.17%
#
# Shape before SMOTE: (226980, 30)
# Shape after SMOTE: (453204, 30)
#
# Resampled Fraud Ratio: 50.00%
# Resampled and scaled training data 'Train_Resampled_Scaled_Credit'saved                 to ..\data\processed\Credit_Train_Resampled_Scaled_Credit.csv.
#
# Class Distribution Bar Plot After Class Balancing...
#
# Plot saved to ..\insights\feature_engineering\credit_new_class_count.png
#             Time        V1        V2        V3        V4        V5        V6  \
# 0       1.149234  1.310714 -1.479963  0.058213 -1.541434  0.818437  0.520080
# 1      -0.150917 -0.056665  0.108067  0.873613 -0.729778  0.195190 -0.030999
# 2       0.794158  1.183691 -0.653744  0.077048 -0.676187  0.893231  1.220875
# 3       0.065513  1.146161 -0.513946  0.790471 -0.725348  0.397123  1.551520
# 4      -1.193637  0.972088 -1.194275  0.859748 -1.212180 -0.157105  0.958065
# ...          ...       ...       ...       ...       ...       ...       ...
# 453199  1.653214  0.643035 -0.074022 -0.749975 -0.237721  0.335815 -0.462772
# 453200  1.106236  0.031217  0.115555 -0.168379  0.103328  1.966693 -1.645515
# 453201  0.751902  0.416254  0.461776 -0.239672  0.369516  1.570165  0.520864
# 453202 -0.229627  0.888214 -0.088012  0.265036 -0.056473  0.753866 -0.044622
# 453203 -0.462609 -0.303466 -0.278741  0.313647 -0.283229  0.076666  0.373011
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 0       0.014215  0.641489 -0.018312  ... -0.760135 -0.114507  1.001832
# 1       0.611201  0.489997 -0.020360  ... -0.892635 -1.409402  1.146822
# 2       0.541106 -0.184128  0.789507  ... -0.102734  1.537838 -0.029319
# 3       0.328239 -0.119330  0.997019  ... -0.332270  0.967295  0.668938
# 4       0.188725 -0.144545 -0.451643  ... -1.044048 -0.961633  0.919916
# ...          ...       ...       ...  ...       ...       ...       ...
# 453199  0.167518  0.042935 -0.076506  ...  0.171638 -0.135246  0.311896
# 453200 -1.126340 -2.920246  0.040928  ... -1.671462 -0.419038 -0.104399
# 453201  0.627993 -0.981789 -0.325280  ...  0.206240 -0.826195 -0.566766
# 453202  0.643751 -0.444307  0.705730  ... -1.099511 -1.196055 -0.305705
# 453203  0.208954 -0.196472  0.504002  ... -0.211309  0.243283 -0.453538
#
#              V24       V25       V26       V27       V28    Amount  Class
# 0       1.418833 -0.593265 -0.425813 -0.493744 -0.628815 -0.060453      0
# 1       1.086614 -1.626604 -0.687742 -0.625605 -0.174278 -0.624841      0
# 2       0.154380  0.086865 -0.018471 -0.476599 -0.642930 -0.445212      0
# 3       1.454711 -0.579658 -0.061848 -0.625476 -0.575139 -0.392180      0
# 4      -0.602530 -0.269552 -1.110198 -0.435513 -0.345143 -0.240985      0
# ...          ...       ...       ...       ...       ...       ...    ...
# 453199 -0.196797  0.965279  1.798694  0.277102  0.389880 -0.711325      1
# 453200  1.444821 -0.060210 -1.531135  1.272906  1.726674 -0.739816      1
# 453201 -1.561003  0.918501  0.147025  0.212219  0.775555 -0.723251      1
# 453202 -0.581407  1.251064 -0.791663 -0.347985  0.148824 -0.760014      1
# 453203 -0.603613  0.141331  1.471049  0.039097  1.804656  0.705560      1
#
# [453204 rows x 31 columns]
